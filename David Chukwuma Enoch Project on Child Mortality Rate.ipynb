# %% [markdown]
# DAVID CHUKWUMA ENOCH PROJECT: CHILD AND INFANT MORTALITY RATES

# %%
#Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading Datasets
df1 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\1. youth-mortality-rate.csv")
df2 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\2. number-of-infant-deaths-unwpp.csv")
df3 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\3. child-mortality-by-income-level-of-country.csv")
df4 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\4. Distribution of Causes of Death among Children Aged less than 5 years.csv")
df5 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\5. number-of-maternal-deaths-by-region.csv")
df6 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\6. births-attended-by-health-staff-sdgs.csv")
df7 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\7. global-vaccination-coverage.csv")
df8 = pd.read_csv(r"C:\Users\USER\Desktop\DAVID'S Project\8. health-protection-coverage.csv")

# %%
df1.head()
# Out:
#         Entity Code  Year  Under-fifteen mortality rate
# 0  Afghanistan  AFG  1977                     30.110573
# 1  Afghanistan  AFG  1978                     29.290777
# 2  Afghanistan  AFG  1979                     28.479010
# 3  Afghanistan  AFG  1980                     27.649078
# 4  Afghanistan  AFG  1981                     26.834482

# %%
print(set)
# Out:
# <class 'set'>

# %%
df1 = df1.rename(columns={"Under-fifteen mortality rate": "Youth Mortality Rate"})

# %%
# check Null Values
df1.isnull().any()
# Out:
# Entity                  False
# Code                     True
# Year                    False
# Youth Mortality Rate    False
# dtype: bool

# %%
df1[df1['Code'].isna()==1]
df1.dropna()
# Out:
#             Entity Code  Year  Youth Mortality Rate
# 0      Afghanistan  AFG  1977             30.110573
# 1      Afghanistan  AFG  1978             29.290777
# 2      Afghanistan  AFG  1979             28.479010
# 3      Afghanistan  AFG  1980             27.649078
# 4      Afghanistan  AFG  1981             26.834482
# ...            ...  ...   ...                   ...
# 10510     Zimbabwe  ZWE  2018              6.515447
# 10511     Zimbabwe  ZWE  2019              6.387253
# 10512     Zimbabwe  ZWE  2020              6.259883
# 10513     Zimbabwe  ZWE  2021              5.999933
# 10514     Zimbabwe  ZWE  2022              5.834957
#
# [9492 rows x 4 columns]

# %%
df1.duplicated('Entity')
df1 = df1.drop_duplicates(subset=['Entity'])
df1.head()
# Out:
#           Entity Code  Year  Youth Mortality Rate
# 0    Afghanistan  AFG  1977             30.110573
# 46        Africa  NaN  1990             18.112036
# 79       Albania  ALB  1990              4.676181
# 112      Algeria  DZA  1979             18.178753
# 156      Andorra  AND  1990              1.556325

# %%
df1 = df1.dropna(subset=['Code'])

# %%
df1.duplicated('Youth Mortality Rate')
# Out:
# 0        False
# 79       False
# 112      False
# 156      False
# 189      False
#          ...
# 10227    False
# 10339    False
# 10372    False
# 10427    False
# 10469    False
# Length: 201, dtype: bool

# %%
df1.duplicated('Year')
df1 = df1.drop_duplicates(subset=['Year'])
df1.head()
# Out:
#           Entity Code  Year  Youth Mortality Rate
# 0    Afghanistan  AFG  1977             30.110573
# 79       Albania  ALB  1990              4.676181
# 112      Algeria  DZA  1979             18.178753
# 288    Argentina  ARG  1969              7.897770
# 342      Armenia  ARM  1989              5.465834

# %%
#Visualizing
plt.figure(figsize=(10, 5))
sns.lineplot(data=df1, x='Entity', y='Youth Mortality Rate', marker='o')
plt.title('Youth Mortality Rate')
plt.xlabel('Entity')
plt.ylabel('Youth Mortality Rate')
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
df2.head()
# Out:
#         Entity Code  Year  Deaths - Sex: all - Age: 0 - Variant: estimates
# 0  Afghanistan  AFG  1950                                         109220.0
# 1  Afghanistan  AFG  1951                                         107971.0
# 2  Afghanistan  AFG  1952                                         108140.0
# 3  Afghanistan  AFG  1953                                         108248.0
# 4  Afghanistan  AFG  1954                                         108241.0

# %%
df2 = df2.rename(columns={"Deaths - Sex: all - Age: 0 - Variant: estimates": "Number of Infant Deaths"})

# %%
# check Null Values
df2.isnull().any()
# Out:
# Entity                     False
# Code                        True
# Year                       False
# Number of Infant Deaths    False
# dtype: bool

# %%
df2[df2['Code'].isna()==1]
df2.dropna()
# Out:
#             Entity Code  Year  Number of Infant Deaths
# 0      Afghanistan  AFG  1950                 109220.0
# 1      Afghanistan  AFG  1951                 107971.0
# 2      Afghanistan  AFG  1952                 108140.0
# 3      Afghanistan  AFG  1953                 108248.0
# 4      Afghanistan  AFG  1954                 108241.0
# ...            ...  ...   ...                      ...
# 18939     Zimbabwe  ZWE  2019                  17470.0
# 18940     Zimbabwe  ZWE  2020                  17143.0
# 18941     Zimbabwe  ZWE  2021                  16971.0
# 18942     Zimbabwe  ZWE  2022                  16890.0
# 18943     Zimbabwe  ZWE  2023                  16491.0
#
# [17612 rows x 4 columns]

# %%
df2.duplicated('Entity')
df2 = df2.drop_duplicates(subset=['Entity'])
df2.head()
# Out:
#              Entity Code  Year  Number of Infant Deaths
# 0       Afghanistan  AFG  1950                 109220.0
# 74      Africa (UN)  NaN  1950                1863884.0
# 148         Albania  ALB  1950                   9620.0
# 222         Algeria  DZA  1950                  74078.0
# 296  American Samoa  ASM  1950                     62.0

# %%
df2 = df2.dropna(subset=['Code'])
df2.head()
# Out:
#              Entity Code  Year  Number of Infant Deaths
# 0       Afghanistan  AFG  1950                 109220.0
# 148         Albania  ALB  1950                   9620.0
# 222         Algeria  DZA  1950                  74078.0
# 296  American Samoa  ASM  1950                     62.0
# 444         Andorra  AND  1950                      4.0

# %%
df2 = df2.drop_duplicates(subset=['Number of Infant Deaths'])

# %%
df2 = df2.dropna(subset=['Year'])

# %%
grouped_data = df2.groupby('Entity')['Number of Infant Deaths'].sum()

# %%
df2 = df2[df2['Number of Infant Deaths'] <= 10]

# %%
df2['Year'] = pd.to_datetime(df2['Year'], format='%Y')

# Verify the conversion
print(df2.dtypes)
print(df2.head())
# Out:
# Entity                             object
# Code                               object
# Year                       datetime64[ns]
# Number of Infant Deaths           float64
# dtype: object
#                           Entity Code       Year  Number of Infant Deaths
# 444                      Andorra  AND 1950-01-01                      4.0
# 5328            Falkland Islands  FLK 1950-01-01                      5.0
# 11840                      Nauru  NRU 1950-01-01                      7.0
# 14282               Saint Helena  SHN 1950-01-01                      9.0
# 15392  Sint Maarten (Dutch part)  SXM 1950-01-01                      3.0

# %%
#Plotting a line chart
plt.figure(figsize=(10, 6))
plt.plot(df2['Year'], df2['Number of Infant Deaths'], marker='o', linestyle='-', color='red')
plt.title('Number of Infant Deaths')
plt.xlabel('Year')
plt.ylabel('Number of Infant Deaths')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
df4.head()
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0      MORT_300  Distribution of causes of death among children...   numeric
# 1      MORT_300  Distribution of causes of death among children...   numeric
# 2      MORT_300  Distribution of causes of death among children...   numeric
# 3      MORT_300  Distribution of causes of death among children...   numeric
# 4      MORT_300  Distribution of causes of death among children...   numeric
#
#   ParentLocationCode         ParentLocation Location type SpatialDimValueCode  \
# 0                EMR  Eastern Mediterranean       Country                 AFG
# 1                EMR  Eastern Mediterranean       Country                 AFG
# 2                EMR  Eastern Mediterranean       Country                 AFG
# 3                EMR  Eastern Mediterranean       Country                 AFG
# 4                EMR  Eastern Mediterranean       Country                 AFG
#
# ...

# %%
df4.isnull().any()
# Out:
# IndicatorCode                 False
# Indicator                     False
# ValueType                     False
# ParentLocationCode            False
# ParentLocation                False
# Location type                 False
# SpatialDimValueCode           False
# Location                      False
# Period type                   False
# Period                        False
# IsLatestYear                  False
# Dim1 type                     False
# Dim1                          False
# Dim1ValueCode                 False
# Dim2 type                     False
# Dim2                          False
# Dim2ValueCode                 False
# Dim3 type                      True
# Dim3                           True
# Dim3ValueCode                  True
# DataSourceDimValueCode         True
# DataSource                     True
# FactValueNumericPrefix         True
# FactValueNumeric              False
# FactValueUoM                   True
# FactValueNumericLowPrefix      True
# ...

# %%
df4 = df4.rename(columns={'Location':'Country', 'Period':'Year', 'Indicator':'Causes of Death among Children Aged less than 5 years', 'IndicatorCode':'Cause of Death', 'Dim1ValueCode':'Age Group', 'Dim2':'Disease', 'Dim2ValueCode':'CHILDCAUSE', 'ParentLocation':'Continent'})

# %%
df4.dropna().sum()
# Out:
# Cause of Death                                             0
# Causes of Death among Children Aged less than 5 years      0
# ValueType                                                  0
# ParentLocationCode                                         0
# Continent                                                  0
# Location type                                              0
# SpatialDimValueCode                                        0
# Country                                                    0
# Period type                                                0
# Year                                                       0
# IsLatestYear                                               0
# Dim1 type                                                  0
# Dim1                                                       0
# Age Group                                                  0
# Dim2 type                                                  0
# ...

# %%
df4.duplicated('Country')
df4 = df4.drop_duplicates(subset=['Country', 'Year', 'Age Group'])

# %%
df4.dropna()
# Out:
# Empty DataFrame
# Columns: [Cause of Death, Causes of Death among Children Aged less than 5 years, ValueType, ParentLocationCode, Continent, Location type, SpatialDimValueCode, Country, Period type, Year, IsLatestYear, Dim1 type, Dim1, Age Group, Dim2 type, Disease, CHILDCAUSE, Dim3 type, Dim3, Dim3ValueCode, DataSourceDimValueCode, DataSource, FactValueNumericPrefix, FactValueNumeric, FactValueUoM, FactValueNumericLowPrefix, FactValueNumericLow, FactValueNumericHighPrefix, FactValueNumericHigh, Value, FactValueTranslationID, FactComments, Language, DateModified]
# Index: []
#
# [0 rows x 34 columns]

# %%
df4.head()
# Out:
#    Cause of Death Causes of Death among Children Aged less than 5 years  \
# 0        MORT_300  Distribution of causes of death among children...
# 8        MORT_300  Distribution of causes of death among children...
# 17       MORT_300  Distribution of causes of death among children...
# 22       MORT_300  Distribution of causes of death among children...
# 31       MORT_300  Distribution of causes of death among children...
#
#    ValueType ParentLocationCode              Continent Location type  \
# 0    numeric                EMR  Eastern Mediterranean       Country
# 8    numeric                EMR  Eastern Mediterranean       Country
# 17   numeric                EMR  Eastern Mediterranean       Country
# 22   numeric                EUR                 Europe       Country
# 31   numeric                EUR                 Europe       Country
#
#    SpatialDimValueCode      Country Period type  Year  ...  FactValueUoM  \
# ...

# %%
df4.duplicated('Continent')
# Out:
# 0         False
# 8          True
# 17         True
# 22        False
# 31         True
#           ...
# 143294     True
# 143302     True
# 143309     True
# 143317     True
# 143327     True
# Length: 10476, dtype: bool

# %%
df4 = df4.drop_duplicates(subset=['Continent'])
df4.head()
# Out:
#     Cause of Death Causes of Death among Children Aged less than 5 years  \
# 0         MORT_300  Distribution of causes of death among children...
# 22        MORT_300  Distribution of causes of death among children...
# 47        MORT_300  Distribution of causes of death among children...
# 123       MORT_300  Distribution of causes of death among children...
# 200       MORT_300  Distribution of causes of death among children...
#
#     ValueType ParentLocationCode              Continent Location type  \
# 0     numeric                EMR  Eastern Mediterranean       Country
# 22    numeric                EUR                 Europe       Country
# 47    numeric                AFR                 Africa       Country
# 123   numeric                AMR               Americas       Country
# 200   numeric                WPR        Western Pacific       Country
#
#     SpatialDimValueCode              Country Period type  Year  ...  \
# ...

# %%
plt.figure(figsize=(10, 6))

# Correct syntax
plt.bar(
    df4['Continent'],  # X-axis (categories or labels)
    df4['Disease'],  # Y-axis (values)
    color='gray'  # Optional: Add color for bars
)

# Add labels and title
plt.title('Causes of Death among Children Aged less than 5 years')
plt.xlabel('Continent')
plt.ylabel('Disease')
plt.xticks(rotation=90)
plt.show()

# %%
df5.head()
# Out:
#         Entity Code  Year  Estimated maternal deaths 959828-annotations
# 0  Afghanistan  AFG  1985                 10258.5340                NaN
# 1  Afghanistan  AFG  1986                  8671.9210                NaN
# 2  Afghanistan  AFG  1987                  8488.9600                NaN
# 3  Afghanistan  AFG  1988                  7522.1216                NaN
# 4  Afghanistan  AFG  1989                  7549.7050                NaN

# %%
df5.isnull().any()
df5.dropna()
# Out:
#              Entity Code  Year  Estimated maternal deaths  \
# 6660  United States  USA  1985                  398.26703
# 6661  United States  USA  1986                  410.97113
# 6662  United States  USA  1987                  416.17654
# 6663  United States  USA  1988                  421.33440
# 6664  United States  USA  1989                  420.51560
# 6665  United States  USA  1990                  415.54990
# 6666  United States  USA  1991                  420.61014
# 6667  United States  USA  1992                  417.23764
# 6668  United States  USA  1993                  430.32300
# 6669  United States  USA  1994                  435.89117
# 6670  United States  USA  1995                  441.33688
# 6671  United States  USA  1996                  432.71033
# 6672  United States  USA  1997                  425.09946
# 6673  United States  USA  1998                  430.10693
# 6674  United States  USA  1999                  456.23544
# ...

# %%
df5.duplicated('Entity')
df5 = df5.drop_duplicates(subset=['Entity'])
df5.head()
# Out:
#           Entity Code  Year  Estimated maternal deaths 959828-annotations
# 0    Afghanistan  AFG  1985               10258.534000                NaN
# 36        Africa  NaN  1985              222858.480000                NaN
# 72       Albania  ALB  1985                  40.066902                NaN
# 108      Algeria  DZA  1985                2187.816200                NaN
# 144       Angola  AGO  1985                5698.489000                NaN

# %%
df5 = df5.drop(columns={"959828-annotations"})

# %%
df5.head()
# Out:
#           Entity Code  Year  Estimated maternal deaths
# 0    Afghanistan  AFG  1985               10258.534000
# 36        Africa  NaN  1985              222858.480000
# 72       Albania  ALB  1985                  40.066902
# 108      Algeria  DZA  1985                2187.816200
# 144       Angola  AGO  1985                5698.489000

# %%
df5 = df5.drop(columns={"Code"})

# %%
df5.head()
# Out:
#           Entity  Year  Estimated maternal deaths
# 0    Afghanistan  1985               10258.534000
# 36        Africa  1985              222858.480000
# 72       Albania  1985                  40.066902
# 108      Algeria  1985                2187.816200
# 144       Angola  1985                5698.489000

# %%
df5.duplicated('Estimated maternal deaths')
# Out:
# 0       False
# 36      False
# 72      False
# 108     False
# 144     False
#         ...
# 6876    False
# 6912    False
# 6948    False
# 6984    False
# 7020    False
# Length: 196, dtype: bool

# %%
df5['Year'] = pd.to_datetime(df5['Year'], format='%Y')

# %%
df5.loc[:10000, "Year"]
# Out:
# 0      1985-01-01
# 36     1985-01-01
# 72     1985-01-01
# 108    1985-01-01
# 144    1985-01-01
#           ...
# 6876   1985-01-01
# 6912   1985-01-01
# 6948   1985-01-01
# 6984   1985-01-01
# 7020   1985-01-01
# Name: Year, Length: 196, dtype: datetime64[ns]

# %%
df5.loc[:1000, "Entity"]
# Out:
# 0                 Afghanistan
# 36                     Africa
# 72                    Albania
# 108                   Algeria
# 144                    Angola
# 180       Antigua and Barbuda
# 216                 Argentina
# 252                   Armenia
# 288                      Asia
# 324                 Australia
# 360                   Austria
# 396                Azerbaijan
# 432                   Bahamas
# 468                   Bahrain
# 504                Bangladesh
# 540                  Barbados
# 576                   Belarus
# 612                   Belgium
# 648                    Belize
# 684                     Benin
# 720                    Bhutan
# 756                   Bolivia
# 792    Bosnia and Herzegovina
# 828                  Botswana
# 864                    Brazil
# 900                    Brunei
# 936                  Bulgaria
# 972              Burkina Faso
# Name: Entity, dtype: object

# %%
df5.loc[:1000, "Estimated maternal deaths"]
# Out:
# 0       10258.534000
# 36     222858.480000
# 72         40.066902
# 108      2187.816200
# 144      5698.489000
# 180         0.589864
# 216       669.813840
# 252        47.544624
# 288    326728.060000
# 324        19.720192
# 360         9.167673
# 396       111.485880
# 432         3.336164
# 468         4.806986
# 504     35509.125000
# 540         2.106906
# 576        71.951744
# 612         9.786767
# 648         6.826606
# 684      1480.427500
# 720       167.014600
# 756      1413.486200
# 792        36.052160
# 828       102.967545
# 864      9001.580000
# 900         4.086970
# 936        30.264711
# 972      3101.651400
# Name: Estimated maternal deaths, dtype: float64

# %%
df5 = df5[df5['Estimated maternal deaths'] <= 30]

# %%
plt.figure(figsize=(10, 6))

# Correct syntax
plt.bar(
    df5['Entity'],  # X-axis (categories or labels)
    df5['Estimated maternal deaths'],  # Y-axis (values)
    color='red'  # Optional: Add color for bars
)

# Add labels and title
plt.title('Estimated maternal deaths')
plt.xlabel('Entity')
plt.ylabel('Estimated maternal deaths')
plt.xticks(rotation=90)
plt.show()

# %%
df6.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2000
# 1  Afghanistan  AFG  2003
# 2  Afghanistan  AFG  2006
# 3  Afghanistan  AFG  2008
# 4  Afghanistan  AFG  2010
#
#    Births attended by skilled health staff (% of total)
# 0                                               12.4
# 1                                               14.3
# 2                                               18.9
# 3                                               24.0
# 4                                               34.3

# %%
df6.isnull().any()
# Out:
# Entity                                                  False
# Code                                                     True
# Year                                                    False
# Births attended by skilled health staff (% of total)    False
# dtype: bool

# %%
df6 =df6.rename(columns = {'Births attended by skilled health staff (% of total)':'Total % of Births by Health Workers'})

# %%
df6.head()
# Out:
#         Entity Code  Year  Total % of Births by Health Workers
# 0  Afghanistan  AFG  2000                                 12.4
# 1  Afghanistan  AFG  2003                                 14.3
# 2  Afghanistan  AFG  2006                                 18.9
# 3  Afghanistan  AFG  2008                                 24.0
# 4  Afghanistan  AFG  2010                                 34.3

# %%
df6[df6['Code'].isna()==1]
# Out:
#                                  Entity Code  Year  \
# 905          East Asia and Pacific (WB)  NaN  1990
# 906          East Asia and Pacific (WB)  NaN  2000
# 907          East Asia and Pacific (WB)  NaN  2010
# 908          East Asia and Pacific (WB)  NaN  2019
# 1021       Europe and Central Asia (WB)  NaN  2000
# 1022       Europe and Central Asia (WB)  NaN  2010
# 1023       Europe and Central Asia (WB)  NaN  2019
# 1024                European Union (27)  NaN  2000
# 1025                European Union (27)  NaN  2010
# 1026                European Union (27)  NaN  2019
# 1292              High-income countries  NaN  2000
# 1293              High-income countries  NaN  2010
# 1294              High-income countries  NaN  2019
# 1605   Latin America and Caribbean (WB)  NaN  1990
# 1606   Latin America and Caribbean (WB)  NaN  2000
# 1607   Latin America and Caribbean (WB)  NaN  2010
# 1608   Latin America and Caribbean (WB)  NaN  2019
# ...

# %%
df6.dropna()
# Out:
#            Entity Code  Year  Total % of Births by Health Workers
# 0     Afghanistan  AFG  2000                                 12.4
# 1     Afghanistan  AFG  2003                                 14.3
# 2     Afghanistan  AFG  2006                                 18.9
# 3     Afghanistan  AFG  2008                                 24.0
# 4     Afghanistan  AFG  2010                                 34.3
# ...           ...  ...   ...                                  ...
# 2980     Zimbabwe  ZWE  2009                                 60.2
# 2981     Zimbabwe  ZWE  2011                                 66.2
# 2982     Zimbabwe  ZWE  2014                                 80.0
# 2983     Zimbabwe  ZWE  2015                                 78.1
# 2984     Zimbabwe  ZWE  2019                                 86.0
#
# [2943 rows x 4 columns]

# %%
df6.duplicated('Code')
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2980     True
# 2981     True
# 2982     True
# 2983     True
# 2984     True
# Length: 2985, dtype: bool

# %%
df6 = df6.drop_duplicates(subset=['Code'])
df6.head()
# Out:
#             Entity Code  Year  Total % of Births by Health Workers
# 0      Afghanistan  AFG  2000                                 12.4
# 12         Albania  ALB  1989                                 92.7
# 32         Algeria  DZA  1992                                 76.5
# 38  American Samoa  ASM  2002                                100.0
# 39         Andorra  AND  2015                                100.0

# %%
df6 = df6[df6['Entity'].notnull() & df6['Year'].notnull()]
df6
# Out:
#               Entity      Code  Year  Total % of Births by Health Workers
# 0        Afghanistan       AFG  2000                            12.400000
# 12           Albania       ALB  1989                            92.700000
# 32           Algeria       DZA  1992                            76.500000
# 38    American Samoa       ASM  2002                           100.000000
# 39           Andorra       AND  2015                           100.000000
# ...              ...       ...   ...                                  ...
# 2951         Vietnam       VNM  1997                            77.100000
# 2958           World  OWID_WRL  2000                            62.247993
# 2961           Yemen       YEM  1992                            34.300000
# 2967          Zambia       ZMB  1992                            49.800000
# 2976        Zimbabwe       ZWE  1988                            69.600000
#
# [207 rows x 4 columns]

# %%
df6 = df6.dropna(subset=['Total % of Births by Health Workers'])

# %%
df6 = df6.dropna(subset=['Entity'])

# %%
# Filter entities with a threshold value
filtered_df6 = df6[df6["Total % of Births by Health Workers"] > 20]

# %%
# Group by 'Entity' and calculate the mean for each
grouped_data = df6.groupby("Entity")["Total % of Births by Health Workers"].max().reset_index()

# Sort the grouped data for better visualization
grouped_data = grouped_data.sort_values(by="Entity", ascending=False)

# %%
df6 = df6[df6['Total % of Births by Health Workers'] <= 60]

# %%
plt.figure(figsize=(8, 4))

# Correct syntax
plt.bar(
    df6['Entity'],  # X-axis (categories or labels)
    df6['Total % of Births by Health Workers'],  # Y-axis (values)
    color='blue'  # Optional: Add color for bars
)

# Add labels and title
plt.title('Total % of Births by Health Workers')
plt.xlabel('Entity')
plt.ylabel('Total % of Births by Health Workers')
plt.xticks(rotation=90)
plt.show()

# %%
# Assuming df is your DataFrame
heatmap_data = df6.pivot(index="Entity",
          columns="Year", values="Total % of Births by Health Workers")

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="coolwarm")
plt.title("Total % of Births by Health Workers")
plt.xlabel("Year")
plt.ylabel("Entity")
plt.show()

# %%
df7.head()
# Out:
#         Entity Code  Year  BCG (% of one-year-olds immunized)  \
# 0  Afghanistan  AFG  1982                                10.0
# 1  Afghanistan  AFG  1983                                10.0
# 2  Afghanistan  AFG  1984                                11.0
# 3  Afghanistan  AFG  1985                                17.0
# 4  Afghanistan  AFG  1986                                18.0
#
#    HepB3 (% of one-year-olds immunized)  Hib3 (% of one-year-olds immunized)  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    IPV1 (% of one-year-olds immunized)  MCV1 (% of one-year-olds immunized)  \
# ...

# %%
df7.dropna()
# Out:
#          Entity      Code  Year  BCG (% of one-year-olds immunized)  \
# 227      Angola       AGO  2018                                72.0
# 228      Angola       AGO  2019                                69.0
# 229      Angola       AGO  2020                                58.0
# 230      Angola       AGO  2021                                56.0
# 309   Argentina       ARG  2016                                92.0
# ...         ...       ...   ...                                 ...
# 7768      World  OWID_WRL  2017                                89.0
# 7769      World  OWID_WRL  2018                                89.0
# 7770      World  OWID_WRL  2019                                88.0
# 7771      World  OWID_WRL  2020                                85.0
# 7772      World  OWID_WRL  2021                                84.0
#
#       HepB3 (% of one-year-olds immunized)  \
# 227                                   59.0
# 228                                   53.0
# ...

# %%
# Filtering rows for global data
global_data = df7[df7['Entity'] == 'World']

# Selecting vaccination columns
vaccination_columns = [col for col in df7.columns if '(%' in col]

# Calculating global averages by year for all vaccines
global_averages = global_data[['Year'] + vaccination_columns].set_index('Year')

print(global_averages)
# Out:
#       BCG (% of one-year-olds immunized)  \
# Year
# 1980                                15.0
# 1981                                21.0
# 1982                                23.0
# 1983                                36.0
# 1984                                43.0
# 1985                                48.0
# 1986                                52.0
# 1987                                61.0
# 1988                                66.0
# 1989                                70.0
# 1990                                81.0
# 1991                                78.0
# 1992                                78.0
# 1993                                79.0
# 1994                                80.0
# 1995                                80.0
# 1996                                80.0
# 1997                                78.0
# 1998                                79.0
# 1999                                80.0
# 2000                                80.0
# 2001                                80.0
# ...

# %%
# Line plot: Vaccination trends over years
plt.figure(figsize=(10, 6))
for col in vaccination_columns:
    plt.plot(global_averages.index, global_averages[col], label=col)

plt.title('Global Vaccination Coverage Trends')
plt.xlabel('Year')
plt.ylabel('Vaccination Coverage (%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Pivoting the data to create a 2D structure for the heatmap
heatmap_data = global_averages.T  # Transpose for years as columns and vaccines as rows

# Create heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="coolwarm")

# Add titles and labels
plt.title('Global Vaccination Coverage Trends')
plt.xlabel('Year')
plt.ylabel('Vaccine')
plt.show()

# %%
df8.head()
# Out:
#                  Entity Code  Year  Global Health Insurance Coverage
# 0               Albania  ALB  2008                              23.6
# 2        American Samoa  ASM  2009                               3.0
# 3                Angola  AGO  2010                               0.0
# 4   Antigua and Barbuda  ATG  2007                              51.1
# 10           Azerbaijan  AZE  2006                               2.9

# %%
# Rename the column
df8.rename(columns={'Share of population covered by health insurance (ILO (2014))': 'Global Health Insurance Coverage'}, inplace=True)
print(df8.head())
# Out:
#                  Entity Code  Year  Global Health Insurance Coverage
# 0               Albania  ALB  2008                              23.6
# 2        American Samoa  ASM  2009                               3.0
# 3                Angola  AGO  2010                               0.0
# 4   Antigua and Barbuda  ATG  2007                              51.1
# 10           Azerbaijan  AZE  2006                               2.9
# C:\Users\USER\AppData\Local\Temp\ipykernel_4856\2602197074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8.rename(columns={'Share of population covered by health insurance (ILO (2014))': 'Global Health Insurance Coverage'}, inplace=True)

# %%
df8.isnull().sum()
# Out:
# Entity                              0
# Code                                0
# Year                                0
# Global Health Insurance Coverage    0
# dtype: int64

# %%
df8.duplicated()
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 10     False
#        ...
# 145    False
# 149    False
# 159    False
# 160    False
# 161    False
# Length: 68, dtype: bool

# %%
# Group by 'Entity' and calculate the mean for each
grouped_data = df8.groupby("Entity")["Global Health Insurance Coverage"].max().reset_index()

# Sort the grouped data for better visualization
grouped_data = grouped_data.sort_values(by="Entity", ascending=False)

# %%
df8 = df8[df8['Global Health Insurance Coverage'] <= 60]

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df8, x='Entity', y='Global Health Insurance Coverage', marker='o')
plt.title('Global Health Insurance Coverage')
plt.xlabel('Entity')
plt.ylabel('Global Health Insurance Coverage')
plt.grid()
plt.xticks(rotation=90)
plt.show()
